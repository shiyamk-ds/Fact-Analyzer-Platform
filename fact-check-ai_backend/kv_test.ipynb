# %%
from azure.identity import DefaultAzureCredential
from azure.keyvault.secrets import SecretClient
import json
import logging

# %%
# Configure logging
logging.basicConfig(level=logging.DEBUG)
logger = logging.getLogger(__name__)

# %%
KEYVAULT_URI = 'https://kvfactanalysis.vault.azure.net/'

# %%
secret_names = {
    "type": "FB-TYPE",
    "project_id": "FB-PROJETCID",
    "private_key_id": "FB-PRIVATEKEYID",
    "private_key": "FB-PRIVATEKEY",
    "client_email": "FB-CLIENTEMAIL",
    "client_id": "FB-CLIENTID",
    "auth_uri": "FB-AUTHURI",
    "token_uri": "FB-TOKENURI",
    "auth_provider_x509_cert_url": "FB-AUTHPROVIDERCERTURL",
    "client_x509_cert_url": "FB-CLIENTURL",
    "universe_domain": "FB-UNIVERSEDOMAIN"
}

firebase_json = {
    "type": "service_account",
    "project_id": "fact-check257",
    "private_key_id": "5800407e8b1f6d04368c2e935d20e2659dd9e4d0",
    "private_key": """-----BEGIN PRIVATE KEY-----...-----END PRIVATE KEY-----""",
    "client_email": "firebase-adminsdk-fbsvc@fact-check257.iam.gserviceaccount.com",
    "client_id": "101709437156448516768",
    "auth_uri": "https://accounts.google.com/o/oauth2/auth",
    "token_uri": "https://oauth2.googleapis.com/token",
    "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
    "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/firebase-adminsdk-fbsvc%40fact-check257.iam.gserviceaccount.com",
    "universe_domain": "googleapis.com"
}

# %%
def set_keyvault_secrets():
    try:
        # Initialize Key Vault client
        credential = DefaultAzureCredential()
        client = SecretClient(vault_url=KEYVAULT_URI, credential=credential)

        # Set each secret in Key Vault
        for json_key, secret_name in secret_names.items():
            secret_value = firebase_json[json_key]
            client.set_secret(secret_name, secret_value)
            logger.info(f"Successfully set secret: {secret_name}")

    except Exception as e:
        logger.exception(f"Error setting secrets: {e}")
        raise

# Run the function

# %%
set_keyvault_secrets()
# Out:
# INFO:azure.identity._credentials.environment:No environment configuration found.
# INFO:azure.identity._credentials.managed_identity:ManagedIdentityCredential will use IMDS
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://kvfactanalysis.vault.azure.net/secrets/FB-TYPE?api-version=REDACTED'
# Request method: 'PUT'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '0'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'ffe571c4-3b03-11f0-abe6-b0227adee090'
#     'User-Agent': 'azsdk-python-keyvault-secrets/4.9.0 Python/3.11.11 (Windows-10-10.0.19045-SP0)'
# No body was attached to the request
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): kvfactanalysis.vault.azure.net:443
# DEBUG:urllib3.connectionpool:https://kvfactanalysis.vault.azure.net:443 "PUT /secrets/FB-TYPE?api-version=7.5 HTTP/1.1" 401 97
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 401
# ...

# %%
from azure.storage.blob import BlobServiceClient
import json
from firebase_admin import credentials, initialize_app
import logging
import os
from io import BytesIO

# %%
logging.basicConfig(level=logging.DEBUG) 
logger = logging.getLogger(__name__)

# %%
AZURE_STORAGE_ACCOUNT_URL = "https://safactcheck.blob.core.windows.net"
AZURE_STORAGE_KEY = 'imoBXY2yicpv5YiA4JBxc3ckudu/FGc4yxaifh6jF9wLudv/v26tuJqY/gNdAMKprRcAyWtxABIZ+ASteADMBA=='
container_name = "firebase-private-key"
blob_name = "fact-check257-firebase-adminsdk-fbsvc-5800407e8b.json"
local_file_name = "firebase_admin_creds.json"

# %%
def download_pdf(blob_name: str, container_name: str):
    try:
        blob_service_client = BlobServiceClient(
            account_url=AZURE_STORAGE_ACCOUNT_URL, 
            credential=AZURE_STORAGE_KEY
        )
        container_client = blob_service_client.get_container_client(container_name)
        blob_client = container_client.get_blob_client(blob_name)

        stream = BytesIO()
        blob_client.download_blob().readinto(stream)
        stream.seek(0) 
        return stream

    except Exception as e:
        raise

# %%
data = download_pdf(blob_name, container_name)
# Out:
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://safactcheck.blob.core.windows.net/firebase-private-key/fact-check257-firebase-adminsdk-fbsvc-5800407e8b.json'
# Request method: 'GET'
# Request headers:
#     'x-ms-range': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.25.1 Python/3.11.11 (Windows-10-10.0.19045-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'a354f92a-3b06-11f0-bdde-b0227adee090'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): safactcheck.blob.core.windows.net:443
# DEBUG:urllib3.connectionpool:https://safactcheck.blob.core.windows.net:443 "GET /firebase-private-key/fact-check257-firebase-adminsdk-fbsvc-5800407e8b.json HTTP/1.1" 206 2379
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 206
# Response headers:
# ...

# %%
import json

# Convert BytesIO data to JSON string
data.seek(0)
json_content = json.load(data)
print(json.dumps(json_content, indent=2))
# Out:
# {
#   "type": "service_account",
#   "project_id": "fact-check257",
#   "private_key_id": "5800407e8b1f6d04368c2e935d20e2659dd9e4d0",
# ...

# %%
from firebase_admin import credentials, initialize_app


cred = credentials.Certificate(cert=json_content)
firebase_app = initialize_app(cred)

# %%
firebase_app.credential.
